# %% [markdown]
# 1. Согласно принципу SMART, попробуйте расписать кейс кредитного скоринга, разбиравшийся на одном из предыдущих курсов.

# %% [markdown]
# S - расчет кредитного скоринга клиента, задача регрессии цель которой узнать насколько венроятно возвращения заемщиком денежных средств в банк
# M - Скоринговый балл, выше и ниже определенной границы
# A - За счет данных о клиентах банка, обработанных и подготовленных должным образом
# R - Решение актуально и реализуемо
# T - 1 месяц

# %% [markdown]
# 2. Предложить перечень индикаторов оттока для клиента каршеринга. Какие данные мы бы взяли в датасет, предполагая, что в нашем распоряжении есть какие угодно сведения?

# %% [markdown]
# Дата регистрации, возраст, пол, частота использования, средний чек, максимальные и минимальные траты, были ли жалобы на сервис
# или авто, проверить штрафы, когда была последняя поездка. Возможно мало машин в часто используемых человеком районах
